# %% [markdown]
# # 03 - So sánh mô hình
#
# Trình bày bảng so sánh 4 mô hình. Chạy trước: `python -m src.evaluation.evaluate --all-models`

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import pandas as pd
from src.utils.config import load_config

config = load_config()
comp = pd.read_csv(config.output_root / 'reports' / 'model_comparison.csv')
comp.sort_values('macro_f1', ascending=False)

# %%
ax = comp.set_index('model_name')[['accuracy', 'macro_f1', 'weighted_f1', 'top3_accuracy']].plot.bar(figsize=(10, 5))
ax.set_ylabel('Score')
ax.set_title('So sánh các mô hình')
