# %% [markdown]
# # 02 - Kiểm tra chất lượng dữ liệu
#
# Xem ảnh lỗi, ảnh trùng và rò rỉ train/test. Logic: `src/data/validate_images.py`, `src/data/detect_duplicates.py`.
#
# Chạy trước: `python -m src.data.validate_images` và `python -m src.data.detect_duplicates`

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import pandas as pd
from src.utils.config import load_config

config = load_config()
ds = config.output_root / 'dataset'
invalid = pd.read_csv(ds / 'invalid_images.csv')
dup = pd.read_csv(ds / 'duplicate_images.csv')
print('Ảnh lỗi:', len(invalid))
print('Cặp trùng:', len(dup))
print('Cặp trùng cross-split (rò rỉ):', int(dup['cross_split'].sum()) if len(dup) else 0)

# %%
dup[dup['cross_split']].head(20)
