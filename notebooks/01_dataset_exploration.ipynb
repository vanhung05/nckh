# %% [markdown]
# # 01 - Khảo sát dataset
#
# Notebook trình bày kết quả khảo sát dữ liệu. Logic chính nằm trong `src/data/explore_dataset.py`.
#
# Chạy trước: `python -m src.data.explore_dataset`

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import pandas as pd
from src.utils.config import load_config

config = load_config()
dist = pd.read_csv(config.output_root / 'dataset' / 'class_distribution.csv')
dist

# %%
print('Số lớp:', len(dist))
print('Tổng train:', dist['train_count'].sum())
print('Tổng test :', dist['test_count'].sum())
dist.sort_values('total_count', ascending=False).head(10)
